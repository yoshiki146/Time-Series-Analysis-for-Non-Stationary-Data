# %% [markdown]
# ### Problem 1

# %%
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline 
import math 
import seaborn as sns

# %%
n=100
epsilon_ts=np.random.randn(n)
epsilon_rwd= np.random.normal(0, math.sqrt(0.5),n).reshape(n,-1)
t=np.arange(1,n+1).reshape(n,-1)  # t starts from one
y_ts_100=[]
y_rwd_100=[]
y_ts_100.append(1+epsilon_ts[0])
y_rwd_100.append(1+epsilon_rwd[0])
for t in np.arange(1,n):
    y_ts_100.append(1+t+epsilon_ts[t])
    y_rwd_100.append(1+y_rwd_100[t-1]+epsilon_rwd[t])   # len(y)  :100

# %%
n=500
epsilon_ts=np.random.randn(n)
epsilon_rwd= np.random.normal(0, math.sqrt(0.5),n).reshape(n,-1)
t=np.arange(1,n+1).reshape(n,-1)   
y_ts_500=[]
y_rwd_500=[]
y_ts_500.append(1+epsilon_ts[0])
y_rwd_500.append(1+epsilon_rwd[0])
for t in np.arange(1,n):
    y_ts_500.append(1+t+epsilon_ts[t])
    y_rwd_500.append(1+y_rwd_500[t-1]+epsilon_rwd[t])

# %%
n=1000
epsilon_ts=np.random.randn(n)
epsilon_rwd= np.random.normal(0, math.sqrt(0.5),n).reshape(n,-1)
t=np.arange(1,n+1).reshape(n,-1)
y_ts_1000=[]
y_rwd_1000=[]
y_ts_1000.append(1+epsilon_ts[0])
y_rwd_1000.append(1+epsilon_rwd[0])
for t in np.arange(1,n):
    y_ts_1000.append(1+t+epsilon_ts[t])
    y_rwd_1000.append(1+y_rwd_1000[t-1]+epsilon_rwd[t])

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(16,10))
plt.subplot(231); plt.plot(y_ts_100); plt.title('TS(n=100)')
plt.subplot(232); plt.plot(y_ts_500); plt.title('TS(n=500)')
plt.subplot(233); plt.plot(y_ts_1000); plt.title('TS(n=1000)')
plt.subplot(234); plt.plot(y_rwd_100); plt.title('RW-D(n=100)')
plt.subplot(235); plt.plot(y_rwd_500); plt.title('RW-D(n=500)')
plt.subplot(236); plt.plot(y_rwd_1000); plt.title('RW-D(n=1000)')
# plt.savefig('assign1_prob1a')
plt.show()

# %% [markdown]
# ### Problem 3

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline
from sklearn.linear_model import LinearRegression
import seaborn as sns
import statsmodels
import statsmodels.api as sm
import scipy

# %% [markdown]
# |                     | n=100  | n=500  | n=1000 |
# |---------------------|--------|--------|--------|
# | $\alpha=0.1$ | List1  | List2  | List3  |
# | $\alpha=0.5$ | List4  | List5  | List6  |
# | $\alpha=1$   | List7  | List8  | List9  |
# | $\alpha=10$  | List10 | List11 | List12 |

# %%
J=10000
n=100  # change here according to the table
alpha=0.1  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list37=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=500  # change here according to the table
alpha=0.1  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list38=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=1000  # change here according to the table
alpha=0.1  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list39=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=100  # change here according to the table
alpha=0.5  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list40=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=500  # change here according to the table
alpha=0.5  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list41=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=1000  # change here according to the table
alpha=0.5  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list42=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=100  # change here according to the table
alpha=1  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list43=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=500  # change here according to the table
alpha=1  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list44=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=1000  # change here according to the table
alpha=1  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list45=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=100  # change here according to the table
alpha=10  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list46=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=500  # change here according to the table
alpha=10  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list47=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
J=10000
n=1000  # change here according to the table
alpha=10  # change here according to the table
phi=0.9
empty_list=[]
test_stat_list48=empty_list  # change here according to the table
for i in np.arange(J):
    epsilon=np.random.randn(n).reshape(n,-1)
    y=[]
    y_lag=[]
    y.append(alpha+epsilon[0]) 
    for t in np.arange(1,n):
        y.append(alpha+y[t-1]+epsilon[t])  # y_1
    for i in np.arange(0,n-1):
        y_lag.append(y[i])
    y=y[1:n]
    Y_lag=sm.add_constant(y_lag)
    ols3=sm.regression.linear_model.OLS(y,Y_lag)
    results3=ols3.fit()
    alpha=results3.params[0]
    phi=results3.params[1]
    sigma2=results3.scale
    V=12*sigma2/(alpha**2)
    test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
    empty_list.append(test_stat)
empty_list.sort()

# %%
plt.figure(figsize=(16,16))
plt.subplot(431)
plt.hist(test_stat_list, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=0.1, n=100')

plt.subplot(432)
plt.hist(test_stat_list2, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=0.1, n=500')

plt.subplot(433)
plt.hist(test_stat_list3, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=1, n=1000')

plt.subplot(434)
plt.hist(test_stat_list4, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=0.5, n=100')

plt.subplot(435)
plt.hist(test_stat_list5, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=0.5, n=500')

plt.subplot(436)
plt.hist(test_stat_list6, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=0.5, n=1000')

plt.subplot(437)
plt.hist(test_stat_list7, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=1, n=100')

plt.subplot(438)
plt.hist(test_stat_list8, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=1, n=500')

plt.subplot(439)
plt.hist(test_stat_list9, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=1, n=1000')

plt.subplot(4,3,10)
plt.hist(test_stat_list10, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=10, n=100')

plt.subplot(4,3,11)
plt.hist(test_stat_list11, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=10, n=500')

plt.subplot(4,3,12)
plt.hist(test_stat_list12, bins=100,normed=True)
x_axis = np.arange(-10, 5, 0.01); plt.plot(x_axis, scipy.stats.norm.pdf(x_axis,0,1))
plt.xlim(-10,5)
plt.title('alpha=10, n=1000')

plt.show()

# %%
n=500
alpha=10
phi=1
test_stat_list=[]
epsilon=np.random.randn(n).reshape(n,-1)
y=[]
y_lag=[]
y.append(alpha+epsilon[0]) 
for t in np.arange(1,n):
    y.append(alpha+y[t-1]+epsilon[t])  # y_1
for i in np.arange(0,n-1):
    y_lag.append(y[i])
y=y[1:n]
Y_lag=sm.add_constant(y_lag)
ols3=sm.regression.linear_model.OLS(y,Y_lag)
results3=ols3.fit()
alpha=results3.params[0]
phi=results3.params[1]
sigma2=results3.scale
V=12*sigma2/(alpha**2)
test_stat=(n**(3/2)*(phi-1))/(V**(1/2))
test_stat_list.append(test_stat)

# %%
test_stat_list1[500]
# Out:
# -1.7047456492012922

# %%
empty_list[500]==test_stat_list9[500]
# Out:
# True

# %%
print('critical value for list %.d is %.4f' %(1,empty_list[500]))
# Out:
# critical value for list 1 is -1.6908
